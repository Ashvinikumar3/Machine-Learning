# %%
import kagglehub
path = kagglehub.dataset_download("elemento/nyc-yellow-taxi-trip-data")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'nyc-yellow-taxi-trip-data' dataset.
# Path to dataset files: /kaggle/input/nyc-yellow-taxi-trip-data

# %%
import os
print(os.listdir(path))
# Out:
# ['yellow_tripdata_2016-01.csv', 'yellow_tripdata_2016-03.csv', 'yellow_tripdata_2016-02.csv', 'yellow_tripdata_2015-01.csv']

# %%
import pandas as pd
import os

file_path = os.path.join(path, "yellow_tripdata_2016-02.csv")

df = pd.read_csv(file_path)

# %%
df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-02-25 17:24:20   2016-02-25 17:27:20
# 1                2  2016-02-25 23:10:50   2016-02-25 23:31:50
# 2                2  2016-02-01 00:00:01   2016-02-01 00:10:52
# 3                1  2016-02-01 00:00:04   2016-02-01 00:05:16
# 4                2  2016-02-01 00:00:05   2016-02-01 00:20:59
# ...            ...                  ...                   ...
# 11382044         1  2016-02-13 22:38:51   2016-06-24 12:30:49
# 11382045         1  2016-02-13 22:39:42   2016-06-23 02:10:11
# 11382046         1  2016-02-13 22:39:49   2016-06-25 12:32:54
# 11382047         1  2016-02-13 22:42:34   2016-06-26 11:55:57
# 11382048         1  2016-02-13 22:48:20   2016-06-22 20:30:05
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           0.70        -73.947250        40.763771
# 1                       2           5.52        -73.983017        40.750992
# 2                       6           1.99        -73.992340        40.758202
# 3                       1           1.50        -73.981453        40.749722
# 4                       1           5.60        -74.000603        40.729755
# ...                   ...            ...               ...              ...
# 11382044                2           2.60        -73.990425        40.766392
# 11382045                1           2.60        -74.007370        40.743530
# 11382046                2           1.10        -73.921600        40.743774
# 11382047                2          10.10        -73.872925        40.774002
# 11382048                1           8.30        -73.872971        40.774014
#
#           RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                  1                  N         -73.992012         40.735390
# 1                  1                  N         -73.988586         40.758839
# 2                  1                  N         -73.964355         40.757977
# 3                  1                  N         -73.982323         40.763985
# 4                  1                  N         -73.951324         40.669834
# ...              ...                ...                ...               ...
# 11382044           1                  N         -73.961891         40.779392
# 11382045           1                  N         -73.987778         40.763790
# 11382046           1                  N         -73.914467         40.753582
# 11382047           1                  N         -73.973198         40.755211
# 11382048           1                  N         -73.966896         40.801868
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    2          5.0    0.0      0.5        0.00          0.00
# 1                    2         20.0    0.5      0.5        0.00          0.00
# 2                    1          9.5    0.5      0.5        0.70          0.00
# 3                    2          6.5    0.5      0.5        0.00          0.00
# 4                    1         20.0    0.5      0.5        4.00          0.00
# ...                ...          ...    ...      ...         ...           ...
# 11382044             2         14.0    0.0      0.5        0.00          0.00
# 11382045             1         10.5    0.5      0.5        2.35          0.00
# 11382046             2          6.0    0.0      0.5        0.00          0.00
# 11382047             1         28.5    0.0      0.5        6.95          5.54
# 11382048             1         26.0    0.5      0.5        6.55          5.54
#
#           improvement_surcharge  total_amount
# 0                           0.3          5.80
# 1                           0.3         21.30
# 2                           0.3         11.50
# 3                           0.3          7.80
# 4                           0.3         25.30
# ...                         ...           ...
# 11382044                    0.3         14.80
# 11382045                    0.3         14.15
# 11382046                    0.3          6.80
# 11382047                    0.3         41.79
# 11382048                    0.3         39.39
#
# [11382049 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11382049 entries, 0 to 11382048
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   pickup_longitude       float64
#  6   pickup_latitude        float64
#  7   RatecodeID             int64
#  8   store_and_fwd_flag     object
#  9   dropoff_longitude      float64
#  10  dropoff_latitude       float64
#  11  payment_type           int64
#  12  fare_amount            float64
#  13  extra                  float64
#  14  mta_tax                float64
#  15  tip_amount             float64
#  16  tolls_amount           float64
#  17  improvement_surcharge  float64
#  18  total_amount           float64
# dtypes: float64(12), int64(4), object(3)
# memory usage: 1.6+ GB

# %%
df.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-02-25 17:24:20   2016-02-25 17:27:20                2
# 1         2  2016-02-25 23:10:50   2016-02-25 23:31:50                2
# 2         2  2016-02-01 00:00:01   2016-02-01 00:10:52                6
# 3         1  2016-02-01 00:00:04   2016-02-01 00:05:16                1
# 4         2  2016-02-01 00:00:05   2016-02-01 00:20:59                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.70        -73.947250        40.763771           1
# 1           5.52        -73.983017        40.750992           1
# 2           1.99        -73.992340        40.758202           1
# 3           1.50        -73.981453        40.749722           1
# 4           5.60        -74.000603        40.729755           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.992012         40.735390             2
# 1                  N         -73.988586         40.758839             2
# 2                  N         -73.964355         40.757977             1
# 3                  N         -73.982323         40.763985             2
# 4                  N         -73.951324         40.669834             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          5.0    0.0      0.5         0.0           0.0
# 1         20.0    0.5      0.5         0.0           0.0
# 2          9.5    0.5      0.5         0.7           0.0
# 3          6.5    0.5      0.5         0.0           0.0
# 4         20.0    0.5      0.5         4.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3           5.8
# 1                    0.3          21.3
# 2                    0.3          11.5
# 3                    0.3           7.8
# 4                    0.3          25.3

# %%
df["tolls_amount"]
# Out:
# 0           0.00
# 1           0.00
# 2           0.00
# 3           0.00
# 4           0.00
#             ...
# 11382044    0.00
# 11382045    0.00
# 11382046    0.00
# 11382047    5.54
# 11382048    5.54
# Name: tolls_amount, Length: 11382049, dtype: float64

# %%
df.tail()
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 11382044         1  2016-02-13 22:38:51   2016-06-24 12:30:49
# 11382045         1  2016-02-13 22:39:42   2016-06-23 02:10:11
# 11382046         1  2016-02-13 22:39:49   2016-06-25 12:32:54
# 11382047         1  2016-02-13 22:42:34   2016-06-26 11:55:57
# 11382048         1  2016-02-13 22:48:20   2016-06-22 20:30:05
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 11382044                2            2.6        -73.990425        40.766392
# 11382045                1            2.6        -74.007370        40.743530
# 11382046                2            1.1        -73.921600        40.743774
# 11382047                2           10.1        -73.872925        40.774002
# 11382048                1            8.3        -73.872971        40.774014
#
#           RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 11382044           1                  N         -73.961891         40.779392
# 11382045           1                  N         -73.987778         40.763790
# 11382046           1                  N         -73.914467         40.753582
# 11382047           1                  N         -73.973198         40.755211
# 11382048           1                  N         -73.966896         40.801868
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 11382044             2         14.0    0.0      0.5        0.00          0.00
# 11382045             1         10.5    0.5      0.5        2.35          0.00
# 11382046             2          6.0    0.0      0.5        0.00          0.00
# 11382047             1         28.5    0.0      0.5        6.95          5.54
# 11382048             1         26.0    0.5      0.5        6.55          5.54
#
#           improvement_surcharge  total_amount
# 11382044                    0.3         14.80
# 11382045                    0.3         14.15
# 11382046                    0.3          6.80
# 11382047                    0.3         41.79
# 11382048                    0.3         39.39

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  1.138205e+07     1.138205e+07   1.138205e+07      1.138205e+07
# mean   1.532299e+00     1.655208e+00   5.060763e+00     -7.282504e+01
# std    4.989557e-01     1.311945e+00   4.122976e+03      9.149828e+00
# min    1.000000e+00     0.000000e+00  -3.390584e+06     -1.308291e+02
# 25%    1.000000e+00     1.000000e+00   1.000000e+00     -7.399171e+01
# 50%    2.000000e+00     1.000000e+00   1.660000e+00     -7.398160e+01
# 75%    2.000000e+00     2.000000e+00   3.050000e+00     -7.396679e+01
# max    2.000000e+00     9.000000e+00   1.165853e+07      9.464387e+01
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     1.138205e+07  1.138205e+07       1.138205e+07      1.138205e+07
# mean      4.011798e+01  1.037623e+00      -7.288799e+01      4.015357e+01
# std       5.040509e+00  5.647826e-01       8.898119e+00      4.903239e+00
# min      -7.703949e+01  1.000000e+00      -1.226153e+02     -7.703949e+01
# 25%       4.073639e+01  1.000000e+00      -7.399126e+01      4.073463e+01
# 50%       4.075338e+01  1.000000e+00      -7.397968e+01      4.075377e+01
# 75%       4.076789e+01  1.000000e+00      -7.396230e+01      4.076934e+01
# max       5.934835e+01  9.900000e+01       3.889659e+01      4.053167e+02
#
#        payment_type   fare_amount         extra       mta_tax    tip_amount  \
# count  1.138205e+07  1.138205e+07  1.138205e+07  1.138205e+07  1.138205e+07
# mean   1.331287e+00  1.241413e+01  3.302671e-01  4.977197e-01  1.772410e+00
# std    4.859976e-01  7.095194e+01  5.681833e-01  5.182089e-02  2.505291e+00
# min    1.000000e+00 -4.500000e+02 -4.760000e+01 -1.000000e+00 -3.500000e+01
# 25%    1.000000e+00  6.500000e+00  0.000000e+00  5.000000e-01  0.000000e+00
# 50%    1.000000e+00  9.000000e+00  0.000000e+00  5.000000e-01  1.350000e+00
# 75%    2.000000e+00  1.400000e+01  5.000000e-01  5.000000e-01  2.350000e+00
# max    4.000000e+00  1.548104e+05  6.379700e+02  8.050000e+01  6.221100e+02
#
#        tolls_amount  improvement_surcharge  total_amount
# count  1.138205e+07           1.138205e+07  1.138205e+07
# mean   2.884042e-01           2.997138e-01  1.560264e+01
# std    1.655873e+00           1.239174e-02  7.140526e+01
# min   -9.999000e+01          -3.000000e-01 -4.503000e+02
# 25%    0.000000e+00           3.000000e-01  8.300000e+00
# 50%    0.000000e+00           3.000000e-01  1.175000e+01
# 75%    0.000000e+00           3.000000e-01  1.716000e+01
# max    9.130000e+02           3.000000e-01  1.548321e+05

# %%
df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-02-25 17:24:20   2016-02-25 17:27:20
# 1                2  2016-02-25 23:10:50   2016-02-25 23:31:50
# 2                2  2016-02-01 00:00:01   2016-02-01 00:10:52
# 3                1  2016-02-01 00:00:04   2016-02-01 00:05:16
# 4                2  2016-02-01 00:00:05   2016-02-01 00:20:59
# ...            ...                  ...                   ...
# 11382044         1  2016-02-13 22:38:51   2016-06-24 12:30:49
# 11382045         1  2016-02-13 22:39:42   2016-06-23 02:10:11
# 11382046         1  2016-02-13 22:39:49   2016-06-25 12:32:54
# 11382047         1  2016-02-13 22:42:34   2016-06-26 11:55:57
# 11382048         1  2016-02-13 22:48:20   2016-06-22 20:30:05
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           0.70        -73.947250        40.763771
# 1                       2           5.52        -73.983017        40.750992
# 2                       6           1.99        -73.992340        40.758202
# 3                       1           1.50        -73.981453        40.749722
# 4                       1           5.60        -74.000603        40.729755
# ...                   ...            ...               ...              ...
# 11382044                2           2.60        -73.990425        40.766392
# 11382045                1           2.60        -74.007370        40.743530
# 11382046                2           1.10        -73.921600        40.743774
# 11382047                2          10.10        -73.872925        40.774002
# 11382048                1           8.30        -73.872971        40.774014
#
#           RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                  1                  N         -73.992012         40.735390
# 1                  1                  N         -73.988586         40.758839
# 2                  1                  N         -73.964355         40.757977
# 3                  1                  N         -73.982323         40.763985
# 4                  1                  N         -73.951324         40.669834
# ...              ...                ...                ...               ...
# 11382044           1                  N         -73.961891         40.779392
# 11382045           1                  N         -73.987778         40.763790
# 11382046           1                  N         -73.914467         40.753582
# 11382047           1                  N         -73.973198         40.755211
# 11382048           1                  N         -73.966896         40.801868
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    2          5.0    0.0      0.5        0.00          0.00
# 1                    2         20.0    0.5      0.5        0.00          0.00
# 2                    1          9.5    0.5      0.5        0.70          0.00
# 3                    2          6.5    0.5      0.5        0.00          0.00
# 4                    1         20.0    0.5      0.5        4.00          0.00
# ...                ...          ...    ...      ...         ...           ...
# 11382044             2         14.0    0.0      0.5        0.00          0.00
# 11382045             1         10.5    0.5      0.5        2.35          0.00
# 11382046             2          6.0    0.0      0.5        0.00          0.00
# 11382047             1         28.5    0.0      0.5        6.95          5.54
# 11382048             1         26.0    0.5      0.5        6.55          5.54
#
#           improvement_surcharge  total_amount
# 0                           0.3          5.80
# 1                           0.3         21.30
# 2                           0.3         11.50
# 3                           0.3          7.80
# 4                           0.3         25.30
# ...                         ...           ...
# 11382044                    0.3         14.80
# 11382045                    0.3         14.15
# 11382046                    0.3          6.80
# 11382047                    0.3         41.79
# 11382048                    0.3         39.39
#
# [11382049 rows x 19 columns]

# %%
df["store_and_fwd_flag"].value_counts()
# Out:
# store_and_fwd_flag
# N    11316527
# Y       65522
# Name: count, dtype: int64

# %%
df['store_and_fwd_flag'] = df['store_and_fwd_flag'].replace({'N': 0, 'Y': 1})
# Out:
# /tmp/ipython-input-4125022579.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['store_and_fwd_flag'] = df['store_and_fwd_flag'].replace({'N': 0, 'Y': 1})

# %%
df['store_and_fwd_flag'].value_counts()
# Out:
# store_and_fwd_flag
# 0    11316527
# 1       65522
# Name: count, dtype: int64

# %%
df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-02-25 17:24:20   2016-02-25 17:27:20
# 1                2  2016-02-25 23:10:50   2016-02-25 23:31:50
# 2                2  2016-02-01 00:00:01   2016-02-01 00:10:52
# 3                1  2016-02-01 00:00:04   2016-02-01 00:05:16
# 4                2  2016-02-01 00:00:05   2016-02-01 00:20:59
# ...            ...                  ...                   ...
# 11382044         1  2016-02-13 22:38:51   2016-06-24 12:30:49
# 11382045         1  2016-02-13 22:39:42   2016-06-23 02:10:11
# 11382046         1  2016-02-13 22:39:49   2016-06-25 12:32:54
# 11382047         1  2016-02-13 22:42:34   2016-06-26 11:55:57
# 11382048         1  2016-02-13 22:48:20   2016-06-22 20:30:05
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           0.70        -73.947250        40.763771
# 1                       2           5.52        -73.983017        40.750992
# 2                       6           1.99        -73.992340        40.758202
# 3                       1           1.50        -73.981453        40.749722
# 4                       1           5.60        -74.000603        40.729755
# ...                   ...            ...               ...              ...
# 11382044                2           2.60        -73.990425        40.766392
# 11382045                1           2.60        -74.007370        40.743530
# 11382046                2           1.10        -73.921600        40.743774
# 11382047                2          10.10        -73.872925        40.774002
# 11382048                1           8.30        -73.872971        40.774014
#
#           RatecodeID  store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0                  1                   0         -73.992012         40.735390
# 1                  1                   0         -73.988586         40.758839
# 2                  1                   0         -73.964355         40.757977
# 3                  1                   0         -73.982323         40.763985
# 4                  1                   0         -73.951324         40.669834
# ...              ...                 ...                ...               ...
# 11382044           1                   0         -73.961891         40.779392
# 11382045           1                   0         -73.987778         40.763790
# 11382046           1                   0         -73.914467         40.753582
# 11382047           1                   0         -73.973198         40.755211
# 11382048           1                   0         -73.966896         40.801868
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                    2          5.0    0.0      0.5        0.00          0.00
# 1                    2         20.0    0.5      0.5        0.00          0.00
# 2                    1          9.5    0.5      0.5        0.70          0.00
# 3                    2          6.5    0.5      0.5        0.00          0.00
# 4                    1         20.0    0.5      0.5        4.00          0.00
# ...                ...          ...    ...      ...         ...           ...
# 11382044             2         14.0    0.0      0.5        0.00          0.00
# 11382045             1         10.5    0.5      0.5        2.35          0.00
# 11382046             2          6.0    0.0      0.5        0.00          0.00
# 11382047             1         28.5    0.0      0.5        6.95          5.54
# 11382048             1         26.0    0.5      0.5        6.55          5.54
#
#           improvement_surcharge  total_amount
# 0                           0.3          5.80
# 1                           0.3         21.30
# 2                           0.3         11.50
# 3                           0.3          7.80
# 4                           0.3         25.30
# ...                         ...           ...
# 11382044                    0.3         14.80
# 11382045                    0.3         14.15
# 11382046                    0.3          6.80
# 11382047                    0.3         41.79
# 11382048                    0.3         39.39
#
# [11382049 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11382049 entries, 0 to 11382048
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   pickup_longitude       float64
#  6   pickup_latitude        float64
#  7   RatecodeID             int64
#  8   store_and_fwd_flag     int64
#  9   dropoff_longitude      float64
#  10  dropoff_latitude       float64
#  11  payment_type           int64
#  12  fare_amount            float64
#  13  extra                  float64
#  14  mta_tax                float64
#  15  tip_amount             float64
#  16  tolls_amount           float64
#  17  improvement_surcharge  float64
#  18  total_amount           float64
# dtypes: float64(12), int64(5), object(2)
# memory usage: 1.6+ GB

# %%
df.drop("tpep_pickup_datetime", axis=1, inplace=True)

# %%
df.drop("tpep_dropoff_datetime", axis=1, inplace=True)

# %%
df
# Out:
#           VendorID  passenger_count  trip_distance  pickup_longitude  \
# 0                2                2           0.70        -73.947250
# 1                2                2           5.52        -73.983017
# 2                2                6           1.99        -73.992340
# 3                1                1           1.50        -73.981453
# 4                2                1           5.60        -74.000603
# ...            ...              ...            ...               ...
# 11382044         1                2           2.60        -73.990425
# 11382045         1                1           2.60        -74.007370
# 11382046         1                2           1.10        -73.921600
# 11382047         1                2          10.10        -73.872925
# 11382048         1                1           8.30        -73.872971
#
#           pickup_latitude  RatecodeID  store_and_fwd_flag  dropoff_longitude  \
# 0               40.763771           1                   0         -73.992012
# 1               40.750992           1                   0         -73.988586
# 2               40.758202           1                   0         -73.964355
# 3               40.749722           1                   0         -73.982323
# 4               40.729755           1                   0         -73.951324
# ...                   ...         ...                 ...                ...
# 11382044        40.766392           1                   0         -73.961891
# 11382045        40.743530           1                   0         -73.987778
# 11382046        40.743774           1                   0         -73.914467
# 11382047        40.774002           1                   0         -73.973198
# 11382048        40.774014           1                   0         -73.966896
#
#           dropoff_latitude  payment_type  fare_amount  extra  mta_tax  \
# 0                40.735390             2          5.0    0.0      0.5
# 1                40.758839             2         20.0    0.5      0.5
# 2                40.757977             1          9.5    0.5      0.5
# 3                40.763985             2          6.5    0.5      0.5
# 4                40.669834             1         20.0    0.5      0.5
# ...                    ...           ...          ...    ...      ...
# 11382044         40.779392             2         14.0    0.0      0.5
# 11382045         40.763790             1         10.5    0.5      0.5
# 11382046         40.753582             2          6.0    0.0      0.5
# 11382047         40.755211             1         28.5    0.0      0.5
# 11382048         40.801868             1         26.0    0.5      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0               0.00          0.00                    0.3          5.80
# 1               0.00          0.00                    0.3         21.30
# 2               0.70          0.00                    0.3         11.50
# 3               0.00          0.00                    0.3          7.80
# 4               4.00          0.00                    0.3         25.30
# ...              ...           ...                    ...           ...
# 11382044        0.00          0.00                    0.3         14.80
# 11382045        2.35          0.00                    0.3         14.15
# 11382046        0.00          0.00                    0.3          6.80
# 11382047        6.95          5.54                    0.3         41.79
# 11382048        6.55          5.54                    0.3         39.39
#
# [11382049 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11382049 entries, 0 to 11382048
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   passenger_count        int64
#  2   trip_distance          float64
#  3   pickup_longitude       float64
#  4   pickup_latitude        float64
#  5   RatecodeID             int64
#  6   store_and_fwd_flag     int64
#  7   dropoff_longitude      float64
#  8   dropoff_latitude       float64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
# dtypes: float64(12), int64(5)
# memory usage: 1.4 GB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.drop("pickup_longitude", axis=1, inplace=True)

# %%
df.drop("pickup_latitude", axis=1, inplace=True)

# %%
df.drop("dropoff_longitude", axis=1, inplace=True)

# %%
df.drop("dropoff_latitude", axis=1, inplace=True)

# %%
df
# Out:
#           VendorID  passenger_count  trip_distance  RatecodeID  \
# 0                2                2           0.70           1
# 1                2                2           5.52           1
# 2                2                6           1.99           1
# 3                1                1           1.50           1
# 4                2                1           5.60           1
# ...            ...              ...            ...         ...
# 11382044         1                2           2.60           1
# 11382045         1                1           2.60           1
# 11382046         1                2           1.10           1
# 11382047         1                2          10.10           1
# 11382048         1                1           8.30           1
#
#           store_and_fwd_flag  payment_type  fare_amount  extra  mta_tax  \
# 0                          0             2          5.0    0.0      0.5
# 1                          0             2         20.0    0.5      0.5
# 2                          0             1          9.5    0.5      0.5
# 3                          0             2          6.5    0.5      0.5
# 4                          0             1         20.0    0.5      0.5
# ...                      ...           ...          ...    ...      ...
# 11382044                   0             2         14.0    0.0      0.5
# 11382045                   0             1         10.5    0.5      0.5
# 11382046                   0             2          6.0    0.0      0.5
# 11382047                   0             1         28.5    0.0      0.5
# 11382048                   0             1         26.0    0.5      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0               0.00          0.00                    0.3          5.80
# 1               0.00          0.00                    0.3         21.30
# 2               0.70          0.00                    0.3         11.50
# 3               0.00          0.00                    0.3          7.80
# 4               4.00          0.00                    0.3         25.30
# ...              ...           ...                    ...           ...
# 11382044        0.00          0.00                    0.3         14.80
# 11382045        2.35          0.00                    0.3         14.15
# 11382046        0.00          0.00                    0.3          6.80
# 11382047        6.95          5.54                    0.3         41.79
# 11382048        6.55          5.54                    0.3         39.39
#
# [11382049 rows x 13 columns]

# %%
df["RatecodeID"].value_counts()
# Out:
# RatecodeID
# 1     11108889
# 2       216701
# 5        32878
# 3        18498
# 4         4686
# 99         290
# 6          107
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# VendorID                 0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df.corr()
# Out:
#                        VendorID  passenger_count  trip_distance  RatecodeID  \
# VendorID               1.000000         0.295057      -0.000558   -0.003313
# passenger_count        0.295057         1.000000       0.000181   -0.006764
# trip_distance         -0.000558         0.000181       1.000000    0.019980
# RatecodeID            -0.003313        -0.006764       0.019980    1.000000
# store_and_fwd_flag    -0.081177        -0.023419       0.000023    0.032375
# payment_type          -0.016011         0.008996       0.000764   -0.000547
# fare_amount            0.000995         0.000922       0.031668    0.039021
# extra                 -0.002898        -0.000007       0.001059    0.011514
# mta_tax                0.002275         0.004208      -0.001059   -0.221865
# tip_amount             0.010039        -0.003472       0.000282    0.141187
# tolls_amount           0.005903         0.006308       0.000362    0.164962
# improvement_surcharge -0.018869        -0.001960      -0.000330   -0.073481
# total_amount           0.001453         0.000944       0.031493    0.047470
#
#                        store_and_fwd_flag  payment_type  fare_amount  \
# VendorID                        -0.081177     -0.016011     0.000995
# passenger_count                 -0.023419      0.008996     0.000922
# trip_distance                    0.000023      0.000764     0.031668
# RatecodeID                       0.032375     -0.000547     0.039021
# store_and_fwd_flag               1.000000      0.011586     0.006195
# payment_type                     0.011586      1.000000    -0.008619
# fare_amount                      0.006195     -0.008619     1.000000
# extra                            0.003331     -0.015866     0.054760
# mta_tax                         -0.004809     -0.029948    -0.007929
# tip_amount                       0.009761     -0.482194     0.086278
# tolls_amount                     0.025424     -0.034456     0.072473
# improvement_surcharge           -0.001363     -0.074635    -0.002109
# total_amount                     0.007110     -0.026442     0.998789
#
#                           extra   mta_tax  tip_amount  tolls_amount  \
# VendorID              -0.002898  0.002275    0.010039      0.005903
# passenger_count       -0.000007  0.004208   -0.003472      0.006308
# trip_distance          0.001059 -0.001059    0.000282      0.000362
# RatecodeID             0.011514 -0.221865    0.141187      0.164962
# store_and_fwd_flag     0.003331 -0.004809    0.009761      0.025424
# payment_type          -0.015866 -0.029948   -0.482194     -0.034456
# fare_amount            0.054760 -0.007929    0.086278      0.072473
# extra                  1.000000  0.241235    0.051142      0.028740
# mta_tax                0.241235  1.000000   -0.085670     -0.153320
# tip_amount             0.051142 -0.085670    1.000000      0.357568
# tolls_amount           0.028740 -0.153320    0.357568      1.000000
# improvement_surcharge  0.017729  0.366452    0.013846      0.004206
# total_amount           0.065008 -0.011731    0.129455      0.107866
#
#                        improvement_surcharge  total_amount
# VendorID                           -0.018869      0.001453
# passenger_count                    -0.001960      0.000944
# trip_distance                      -0.000330      0.031493
# RatecodeID                         -0.073481      0.047470
# store_and_fwd_flag                 -0.001363      0.007110
# payment_type                       -0.074635     -0.026442
# fare_amount                        -0.002109      0.998789
# extra                               0.017729      0.065008
# mta_tax                             0.366452     -0.011731
# tip_amount                          0.013846      0.129455
# tolls_amount                        0.004206      0.107866
# improvement_surcharge               1.000000     -0.000931
# total_amount                       -0.000931      1.000000

# %%
df["payment_type"].value_counts()
# Out:
# payment_type
# 1    7680359
# 2    3647035
# 3      40274
# 4      14381
# Name: count, dtype: int64

# %%
df
# Out:
#           VendorID  passenger_count  trip_distance  RatecodeID  \
# 0                2                2           0.70           1
# 1                2                2           5.52           1
# 2                2                6           1.99           1
# 3                1                1           1.50           1
# 4                2                1           5.60           1
# ...            ...              ...            ...         ...
# 11382044         1                2           2.60           1
# 11382045         1                1           2.60           1
# 11382046         1                2           1.10           1
# 11382047         1                2          10.10           1
# 11382048         1                1           8.30           1
#
#           store_and_fwd_flag  payment_type  fare_amount  extra  mta_tax  \
# 0                          0             2          5.0    0.0      0.5
# 1                          0             2         20.0    0.5      0.5
# 2                          0             1          9.5    0.5      0.5
# 3                          0             2          6.5    0.5      0.5
# 4                          0             1         20.0    0.5      0.5
# ...                      ...           ...          ...    ...      ...
# 11382044                   0             2         14.0    0.0      0.5
# 11382045                   0             1         10.5    0.5      0.5
# 11382046                   0             2          6.0    0.0      0.5
# 11382047                   0             1         28.5    0.0      0.5
# 11382048                   0             1         26.0    0.5      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0               0.00          0.00                    0.3          5.80
# 1               0.00          0.00                    0.3         21.30
# 2               0.70          0.00                    0.3         11.50
# 3               0.00          0.00                    0.3          7.80
# 4               4.00          0.00                    0.3         25.30
# ...              ...           ...                    ...           ...
# 11382044        0.00          0.00                    0.3         14.80
# 11382045        2.35          0.00                    0.3         14.15
# 11382046        0.00          0.00                    0.3          6.80
# 11382047        6.95          5.54                    0.3         41.79
# 11382048        6.55          5.54                    0.3         39.39
#
# [11382049 rows x 13 columns]

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
X= df.iloc[:, :12]
Y = df.iloc[:, 12:]

# %%
X
# Out:
#           VendorID  passenger_count  trip_distance  RatecodeID  \
# 0                2                2           0.70           1
# 1                2                2           5.52           1
# 2                2                6           1.99           1
# 3                1                1           1.50           1
# 4                2                1           5.60           1
# ...            ...              ...            ...         ...
# 11382044         1                2           2.60           1
# 11382045         1                1           2.60           1
# 11382046         1                2           1.10           1
# 11382047         1                2          10.10           1
# 11382048         1                1           8.30           1
#
#           store_and_fwd_flag  payment_type  fare_amount  extra  mta_tax  \
# 0                          0             2          5.0    0.0      0.5
# 1                          0             2         20.0    0.5      0.5
# 2                          0             1          9.5    0.5      0.5
# 3                          0             2          6.5    0.5      0.5
# 4                          0             1         20.0    0.5      0.5
# ...                      ...           ...          ...    ...      ...
# 11382044                   0             2         14.0    0.0      0.5
# 11382045                   0             1         10.5    0.5      0.5
# 11382046                   0             2          6.0    0.0      0.5
# 11382047                   0             1         28.5    0.0      0.5
# 11382048                   0             1         26.0    0.5      0.5
#
#           tip_amount  tolls_amount  improvement_surcharge
# 0               0.00          0.00                    0.3
# 1               0.00          0.00                    0.3
# 2               0.70          0.00                    0.3
# 3               0.00          0.00                    0.3
# 4               4.00          0.00                    0.3
# ...              ...           ...                    ...
# 11382044        0.00          0.00                    0.3
# 11382045        2.35          0.00                    0.3
# 11382046        0.00          0.00                    0.3
# 11382047        6.95          5.54                    0.3
# 11382048        6.55          5.54                    0.3
#
# [11382049 rows x 12 columns]

# %%
Y
# Out:
#           total_amount
# 0                 5.80
# 1                21.30
# 2                11.50
# 3                 7.80
# 4                25.30
# ...                ...
# 11382044         14.80
# 11382045         14.15
# 11382046          6.80
# 11382047         41.79
# 11382048         39.39
#
# [11382049 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((7625972, 12), (3756077, 12))

# %%
y_train.shape, y_test.shape
# Out:
# ((7625972, 1), (3756077, 1))

# %%
Regression=LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

# %%
model=Regression.fit(X_train, y_train)

# %%
y_pred=model.predict(X_test)

# %%
Y_pred=pd.DataFrame(y_pred)

# %%
Y_pred
# Out:
#                  0
# 0        28.299994
# 1        11.299988
# 2        12.959993
# 3         6.800002
# 4         8.759985
# ...            ...
# 3756072  12.300004
# 3756073   9.300019
# 3756074  11.299962
# 3756075  23.300034
# 3756076   5.550002
#
# [3756077 rows x 1 columns]

# %%
score=r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.9999999931489856

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
ridge=Ridge()
model=ridge.fit(X_train, y_train)
y_pred=ridge.predict(X_test)
mse=mean_squared_error(y_test, y_pred)
score=r2_score(y_test, y_pred)
print(mse)
print(score)
# Out:
# 8.785267951262553e-05
# 0.9999999931490392

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
lasso=Lasso()
model=lasso.fit(X_train, y_train)
y_pred=model.predict(X_test)
mse=mean_squared_error(y_test, y_pred)
score=r2_score(y_test, y_pred)
print(mse)
print(score)
# Out:
# 7.820533227583343
# 0.9993901362267273

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
model=elastic.fit(X_train, y_train)
y_pred=model.predict(X_test)
mse-mean_squared_error(y_test, y_pred)
score=r2_score(y_test, y_pred)
print(mse)
print(score)
# Out:
# 7.820533227583343
# 0.8821447042846012
